# %% [markdown]
# ## Introduction
#
# This example demonstrates how to implement a basic character-level
# recurrent sequence-to-sequence model. We apply it to translating
# short English sentences into short French sentences,
# character-by-character. Note that it is fairly unusual to
# do character-level machine translation, as word-level
# models are more common in this domain.
#
# **Summary of the algorithm**
#
# - We start with input sequences from a domain (e.g. English sentences)
#     and corresponding target sequences from another domain
#     (e.g. French sentences).
# - An encoder LSTM turns input sequences to 2 state vectors
#     (we keep the last LSTM state and discard the outputs).
# - A decoder LSTM is trained to turn the target sequences into
#     the same sequence but offset by one timestep in the future,
#     a training process called "teacher forcing" in this context.
#     It uses as initial state the state vectors from the encoder.
#     Effectively, the decoder learns to generate `targets[t+1...]`
#     given `targets[...t]`, conditioned on the input sequence.
# - In inference mode, when we want to decode unknown input sequences, we:
#     - Encode the input sequence into state vectors
#     - Start with a target sequence of size 1
#         (just the start-of-sequence character)
#     - Feed the state vectors and 1-char target sequence
#         to the decoder to produce predictions for the next character
#     - Sample the next character using these predictions
#         (we simply use argmax).
#     - Append the sampled character to the target sequence
#     - Repeat until we generate the end-of-sequence character or we
#         hit the character limit.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import keras
import os
from pathlib import Path

# %% [markdown]
# ## Download the data

# %%
# !wget "http://www.manythings.org/anki/fra-eng.zip"
# Out:
# --2024-01-07 07:16:13--  http://www.manythings.org/anki/fra-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7833145 (7.5M) [application/zip]
# Saving to: ‘fra-eng.zip’
#
# fra-eng.zip         100%[===================>]   7.47M  6.33MB/s    in 1.2s
#
# 2024-01-07 07:16:15 (6.33 MB/s) - ‘fra-eng.zip’ saved [7833145/7833145]

# %%
fpath = "/content/fra-eng.zip"
os.system(f"unzip -q {fpath}")
# Out:
# 0

# %% [markdown]
# ## Configuration

# %%
dirpath = "/content/"

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = os.path.join(dirpath, "fra.txt")

# %% [markdown]
# ## Prepare the data

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype="float32",
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %% [markdown]
# ## Build the model

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ## Train the model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s_model.keras")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 6s 24ms/step - loss: 1.1256 - accuracy: 0.7381 - val_loss: 1.0622 - val_accuracy: 0.7104
# Epoch 2/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.9335 - accuracy: 0.7484 - val_loss: 0.9620 - val_accuracy: 0.7270
# Epoch 3/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.8365 - accuracy: 0.7674 - val_loss: 0.8685 - val_accuracy: 0.7484
# Epoch 4/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.7498 - accuracy: 0.7872 - val_loss: 0.7711 - val_accuracy: 0.7734
# Epoch 5/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.6736 - accuracy: 0.8074 - val_loss: 0.7161 - val_accuracy: 0.7911
# Epoch 6/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.6301 - accuracy: 0.8169 - val_loss: 0.6793 - val_accuracy: 0.8006
# Epoch 7/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.6010 - accuracy: 0.8243 - val_loss: 0.6595 - val_accuracy: 0.8069
# Epoch 8/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5783 - accuracy: 0.8305 - val_loss: 0.6297 - val_accuracy: 0.8170
# Epoch 9/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5586 - accuracy: 0.8357 - val_loss: 0.6148 - val_accuracy: 0.8211
# Epoch 10/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.5423 - accuracy: 0.8403 - val_loss: 0.6070 - val_accuracy: 0.8219
# Epoch 11/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.5271 - accuracy: 0.8449 - val_loss: 0.6014 - val_accuracy: 0.8243
# Epoch 12/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5121 - accuracy: 0.8491 - val_loss: 0.5691 - val_accuracy: 0.8375
# Epoch 13/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4992 - accuracy: 0.8533 - val_loss: 0.5603 - val_accuracy: 0.8371
# Epoch 14/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4854 - accuracy: 0.8575 - val_loss: 0.5541 - val_accuracy: 0.8366
# Epoch 15/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4736 - accuracy: 0.8607 - val_loss: 0.5431 - val_accuracy: 0.8422
# Epoch 16/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4631 - accuracy: 0.8641 - val_loss: 0.5313 - val_accuracy: 0.8443
# Epoch 17/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4531 - accuracy: 0.8665 - val_loss: 0.5301 - val_accuracy: 0.8448
# Epoch 18/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4434 - accuracy: 0.8690 - val_loss: 0.5168 - val_accuracy: 0.8504
# Epoch 19/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4344 - accuracy: 0.8717 - val_loss: 0.5076 - val_accuracy: 0.8520
# Epoch 20/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4263 - accuracy: 0.8738 - val_loss: 0.5011 - val_accuracy: 0.8520
# Epoch 21/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4180 - accuracy: 0.8762 - val_loss: 0.5002 - val_accuracy: 0.8533
# Epoch 22/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4106 - accuracy: 0.8785 - val_loss: 0.4909 - val_accuracy: 0.8562
# Epoch 23/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4035 - accuracy: 0.8804 - val_loss: 0.4868 - val_accuracy: 0.8560
# Epoch 24/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3964 - accuracy: 0.8825 - val_loss: 0.4827 - val_accuracy: 0.8592
# Epoch 25/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3903 - accuracy: 0.8845 - val_loss: 0.4818 - val_accuracy: 0.8591
# Epoch 26/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3835 - accuracy: 0.8862 - val_loss: 0.4766 - val_accuracy: 0.8603
# Epoch 27/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3777 - accuracy: 0.8878 - val_loss: 0.4691 - val_accuracy: 0.8620
# Epoch 28/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3715 - accuracy: 0.8897 - val_loss: 0.4713 - val_accuracy: 0.8615
# Epoch 29/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3661 - accuracy: 0.8913 - val_loss: 0.4630 - val_accuracy: 0.8636
# Epoch 30/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3608 - accuracy: 0.8922 - val_loss: 0.4595 - val_accuracy: 0.8647
# Epoch 31/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3552 - accuracy: 0.8942 - val_loss: 0.4546 - val_accuracy: 0.8668
# Epoch 32/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3500 - accuracy: 0.8955 - val_loss: 0.4568 - val_accuracy: 0.8652
# Epoch 33/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3451 - accuracy: 0.8970 - val_loss: 0.4545 - val_accuracy: 0.8663
# Epoch 34/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3400 - accuracy: 0.8986 - val_loss: 0.4520 - val_accuracy: 0.8681
# Epoch 35/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3352 - accuracy: 0.9003 - val_loss: 0.4490 - val_accuracy: 0.8692
# Epoch 36/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3304 - accuracy: 0.9016 - val_loss: 0.4478 - val_accuracy: 0.8702
# Epoch 37/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3256 - accuracy: 0.9027 - val_loss: 0.4463 - val_accuracy: 0.8698
# Epoch 38/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3213 - accuracy: 0.9044 - val_loss: 0.4472 - val_accuracy: 0.8689
# Epoch 39/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3167 - accuracy: 0.9055 - val_loss: 0.4489 - val_accuracy: 0.8697
# Epoch 40/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3118 - accuracy: 0.9068 - val_loss: 0.4466 - val_accuracy: 0.8706
# Epoch 41/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3078 - accuracy: 0.9080 - val_loss: 0.4418 - val_accuracy: 0.8715
# Epoch 42/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3036 - accuracy: 0.9092 - val_loss: 0.4432 - val_accuracy: 0.8706
# Epoch 43/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2993 - accuracy: 0.9102 - val_loss: 0.4419 - val_accuracy: 0.8726
# Epoch 44/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2951 - accuracy: 0.9116 - val_loss: 0.4396 - val_accuracy: 0.8733
# Epoch 45/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2911 - accuracy: 0.9131 - val_loss: 0.4408 - val_accuracy: 0.8729
# Epoch 46/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2871 - accuracy: 0.9140 - val_loss: 0.4400 - val_accuracy: 0.8732
# Epoch 47/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2831 - accuracy: 0.9151 - val_loss: 0.4401 - val_accuracy: 0.8728
# Epoch 48/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2791 - accuracy: 0.9165 - val_loss: 0.4415 - val_accuracy: 0.8730
# Epoch 49/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2753 - accuracy: 0.9176 - val_loss: 0.4394 - val_accuracy: 0.8741
# Epoch 50/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2716 - accuracy: 0.9184 - val_loss: 0.4382 - val_accuracy: 0.8746
# Epoch 51/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2677 - accuracy: 0.9195 - val_loss: 0.4379 - val_accuracy: 0.8754
# Epoch 52/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2642 - accuracy: 0.9207 - val_loss: 0.4408 - val_accuracy: 0.8740
# Epoch 53/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2608 - accuracy: 0.9215 - val_loss: 0.4458 - val_accuracy: 0.8736
# Epoch 54/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2571 - accuracy: 0.9231 - val_loss: 0.4390 - val_accuracy: 0.8758
# Epoch 55/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2534 - accuracy: 0.9240 - val_loss: 0.4393 - val_accuracy: 0.8755
# Epoch 56/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2499 - accuracy: 0.9252 - val_loss: 0.4427 - val_accuracy: 0.8752
# Epoch 57/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2463 - accuracy: 0.9261 - val_loss: 0.4419 - val_accuracy: 0.8760
# Epoch 58/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2430 - accuracy: 0.9269 - val_loss: 0.4405 - val_accuracy: 0.8763
# Epoch 59/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2397 - accuracy: 0.9279 - val_loss: 0.4465 - val_accuracy: 0.8746
# Epoch 60/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2372 - accuracy: 0.9287 - val_loss: 0.4446 - val_accuracy: 0.8752
# Epoch 61/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2333 - accuracy: 0.9297 - val_loss: 0.4433 - val_accuracy: 0.8761
# Epoch 62/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2305 - accuracy: 0.9306 - val_loss: 0.4476 - val_accuracy: 0.8753
# Epoch 63/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2273 - accuracy: 0.9318 - val_loss: 0.4488 - val_accuracy: 0.8757
# Epoch 64/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2242 - accuracy: 0.9321 - val_loss: 0.4493 - val_accuracy: 0.8758
# Epoch 65/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2213 - accuracy: 0.9331 - val_loss: 0.4523 - val_accuracy: 0.8759
# Epoch 66/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2180 - accuracy: 0.9342 - val_loss: 0.4524 - val_accuracy: 0.8758
# Epoch 67/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2154 - accuracy: 0.9349 - val_loss: 0.4541 - val_accuracy: 0.8766
# Epoch 68/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2126 - accuracy: 0.9358 - val_loss: 0.4537 - val_accuracy: 0.8766
# Epoch 69/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2095 - accuracy: 0.9369 - val_loss: 0.4556 - val_accuracy: 0.8759
# Epoch 70/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2068 - accuracy: 0.9374 - val_loss: 0.4571 - val_accuracy: 0.8764
# Epoch 71/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2043 - accuracy: 0.9383 - val_loss: 0.4601 - val_accuracy: 0.8768
# Epoch 72/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2011 - accuracy: 0.9389 - val_loss: 0.4617 - val_accuracy: 0.8770
# Epoch 73/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1985 - accuracy: 0.9400 - val_loss: 0.4641 - val_accuracy: 0.8756
# Epoch 74/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1957 - accuracy: 0.9410 - val_loss: 0.4642 - val_accuracy: 0.8761
# Epoch 75/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1931 - accuracy: 0.9417 - val_loss: 0.4643 - val_accuracy: 0.8766
# Epoch 76/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1907 - accuracy: 0.9422 - val_loss: 0.4660 - val_accuracy: 0.8769
# Epoch 77/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1878 - accuracy: 0.9430 - val_loss: 0.4689 - val_accuracy: 0.8772
# Epoch 78/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1854 - accuracy: 0.9438 - val_loss: 0.4719 - val_accuracy: 0.8769
# Epoch 79/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1830 - accuracy: 0.9446 - val_loss: 0.4772 - val_accuracy: 0.8758
# Epoch 80/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1805 - accuracy: 0.9455 - val_loss: 0.4745 - val_accuracy: 0.8770
# Epoch 81/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1783 - accuracy: 0.9458 - val_loss: 0.4793 - val_accuracy: 0.8765
# Epoch 82/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1755 - accuracy: 0.9468 - val_loss: 0.4794 - val_accuracy: 0.8764
# Epoch 83/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1733 - accuracy: 0.9472 - val_loss: 0.4839 - val_accuracy: 0.8767
# Epoch 84/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1711 - accuracy: 0.9479 - val_loss: 0.4842 - val_accuracy: 0.8766
# Epoch 85/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1688 - accuracy: 0.9488 - val_loss: 0.4854 - val_accuracy: 0.8766
# Epoch 86/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1661 - accuracy: 0.9497 - val_loss: 0.4898 - val_accuracy: 0.8759
# Epoch 87/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1647 - accuracy: 0.9502 - val_loss: 0.4911 - val_accuracy: 0.8764
# Epoch 88/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1621 - accuracy: 0.9508 - val_loss: 0.4916 - val_accuracy: 0.8758
# Epoch 89/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1602 - accuracy: 0.9513 - val_loss: 0.4972 - val_accuracy: 0.8759
# Epoch 90/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1581 - accuracy: 0.9521 - val_loss: 0.4966 - val_accuracy: 0.8754
# Epoch 91/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1559 - accuracy: 0.9527 - val_loss: 0.5000 - val_accuracy: 0.8763
# Epoch 92/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1539 - accuracy: 0.9532 - val_loss: 0.5074 - val_accuracy: 0.8744
# Epoch 93/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1519 - accuracy: 0.9540 - val_loss: 0.5045 - val_accuracy: 0.8759
# Epoch 94/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1498 - accuracy: 0.9545 - val_loss: 0.5047 - val_accuracy: 0.8762
# Epoch 95/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1481 - accuracy: 0.9550 - val_loss: 0.5058 - val_accuracy: 0.8767
# Epoch 96/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1463 - accuracy: 0.9555 - val_loss: 0.5130 - val_accuracy: 0.8758
# Epoch 97/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1444 - accuracy: 0.9560 - val_loss: 0.5146 - val_accuracy: 0.8759
# Epoch 98/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1423 - accuracy: 0.9567 - val_loss: 0.5133 - val_accuracy: 0.8754
# Epoch 99/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1407 - accuracy: 0.9570 - val_loss: 0.5181 - val_accuracy: 0.8759
# Epoch 100/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1391 - accuracy: 0.9574 - val_loss: 0.5193 - val_accuracy: 0.8753

# %% [markdown]
# ## Run inference (sampling)
#
# 1. encode input and retrieve initial decoder state
# 2. run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token.
# 3. Repeat with the current target token and current states

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s_model.keras")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq, verbose=0)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value, verbose=0
        )

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %% [markdown]
# You can now generate decoded sentences as such:

# %%
for seq_index in range(50):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Faute.
#
# -
# Input sentence: Go.
# Decoded sentence: Faute.
#
# -
# Input sentence: Go.
# Decoded sentence: Faute.
#
# -
# Input sentence: Go.
# Decoded sentence: Faute.
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# -
# Input sentence: Who?
# Decoded sentence: Qui qui nai ?
#
# -
# Input sentence: Wow!
# Decoded sentence: Coout !
#
# -
# Input sentence: Wow!
# Decoded sentence: Coout !
#
# -
# Input sentence: Wow!
# Decoded sentence: Coout !
#
# -
# Input sentence: Duck!
# Decoded sentence: Baissez-vous !
#
# -
# Input sentence: Duck!
# Decoded sentence: Baissez-vous !
#
# -
# Input sentence: Duck!
# Decoded sentence: Baissez-vous !
#
# -
# Input sentence: Fire!
# Decoded sentence: Au fai !
#
# -
# Input sentence: Help!
# Decoded sentence: Salut !
#
# -
# Input sentence: Hide.
# Decoded sentence: Cache-toi.
#
# -
# Input sentence: Hide.
# Decoded sentence: Cache-toi.
#
# -
# Input sentence: Jump!
# Decoded sentence: Saute.
#
# -
# Input sentence: Jump.
# Decoded sentence: Saute.
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attendez !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attendez !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attendez !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attendez !
#
# -
# Input sentence: Wait.
# Decoded sentence: Attendez !
#
# -
# Input sentence: Begin.
# Decoded sentence: Boure !
#
# -
# Input sentence: Begin.
# Decoded sentence: Boure !
#
# -
# Input sentence: Go on.
# Decoded sentence: Va !
#
# -
# Input sentence: Go on.
# Decoded sentence: Va !
#
# -
# Input sentence: Go on.
# Decoded sentence: Va !
